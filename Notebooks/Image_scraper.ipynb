# %% [markdown]
# # Image scraping to train a custom model.
# this is a simple notebook to scrape the images that we need to train our Yolov5 Model.
# Since films usually have specific core camera shot types We'll scrape 4 searches of images:
#
# * Wide Shot with a person in the frame.
# * Close Shot of a person.
# * Medium Shot of a person.
# * Natalie Portman close Shot ( This might overfit the dataset on the commercial but I'll try to clean the dataset and only add a few images of her in teh datasett.)
#
# The images will be saved in a private google Drive and then be imported to Roboflow for annotation and exporting  the dataset to yolov5 compatible type.
# Please note that I won't be scraping a large amount of images because the Annotation task later on is time consuming.

# %% [markdown]
# ##Install and import the library

# %%
# !pip install bing-image-downloader
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
from bing_image_downloader import downloader

# %% [markdown]
# ##Mount the drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ##Set directory

# %%
#set the directory

dir = '/content/drive/MyDrive/image dataset'

# %% [markdown]
# ##Download The Images

# %%
downloader.download('person wide shot', limit = 75, output_dir = dir, adult_filter_off = True)
# Out:
# [%] Downloading Images to /content/drive/MyDrive/image dataset/person wide shot
#
#
# [!!]Indexing page: 1
#
# [%] Indexed 18 Images on Page 1.
#
# ...
#
# [%] Downloading Image #1 from https://ak.picdn.net/shutterstock/videos/6015923/thumb/1.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #2 from https://ak1.picdn.net/shutterstock/videos/15399301/thumb/1.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #3 from https://ak.picdn.net/shutterstock/videos/9732125/thumb/1.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #4 from https://image.freepik.com/free-photo/medium-shot-man-pointing-camera_23-2148242725.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #5 from https://www.researchgate.net/publication/323705555/figure/fig2/AS:612600991739914@1523066866835/A-very-wide-shot-at-1331.png
# [!] Issue getting: https://www.researchgate.net/publication/323705555/figure/fig2/AS:612600991739914@1523066866835/A-very-wide-shot-at-1331.png
# [!] Error:: HTTP Error 403: Forbidden
# ...

# %%
downloader.download('person close shot', limit = 75, output_dir = dir, adult_filter_off = False)
# Out:
# [%] Downloading Images to /content/drive/MyDrive/image dataset/person close shot
#
#
# [!!]Indexing page: 1
#
# [%] Indexed 18 Images on Page 1.
#
# ...
#
# [%] Downloading Image #1 from https://ak.picdn.net/shutterstock/videos/1052477401/thumb/1.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #2 from https://ak.picdn.net/shutterstock/videos/1056897497/thumb/1.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #3 from https://ak.picdn.net/shutterstock/videos/30656377/thumb/8.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #4 from https://ak.picdn.net/shutterstock/videos/1019483431/thumb/12.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #5 from https://www.rd.com/wp-content/uploads/2021/04/3-1_2-Minutes-10-Bullets-via-Amazon.jpg?fit=700,467
# [%] File Downloaded !
#
# [%] Downloading Image #6 from https://static1.bigstockphoto.com/9/7/1/large1500/179183533.jpg
# [%] File Downloaded !
#
# ...

# %%
downloader.download('person medium shot', limit = 75, output_dir = dir, adult_filter_off = False)
# Out:
# [%] Downloading Images to /content/drive/MyDrive/image dataset/person medium shot
#
#
# [!!]Indexing page: 1
#
# [%] Indexed 17 Images on Page 1.
#
# ...
#
# [%] Downloading Image #1 from https://thumbs.dreamstime.com/z/vertical-medium-shot-funny-bald-man-training-exercise-bike-smiling-vertical-medium-shot-funny-bald-man-training-193014224.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #2 from https://davismonique98.files.wordpress.com/2013/11/medium-shot.jpg
# [Error]Invalid image, not saving https://davismonique98.files.wordpress.com/2013/11/medium-shot.jpg
#
# [!] Issue getting: https://davismonique98.files.wordpress.com/2013/11/medium-shot.jpg
# [!] Error:: Invalid image, not saving https://davismonique98.files.wordpress.com/2013/11/medium-shot.jpg
#
# [%] Downloading Image #2 from https://ak9.picdn.net/shutterstock/videos/1028142629/thumb/1.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #3 from https://ak.picdn.net/shutterstock/videos/1024058207/thumb/1.jpg
# ...

# %%
downloader.download('natalie portman close shot', limit = 75, output_dir = dir, adult_filter_off = False)
# Out:
# [%] Downloading Images to /content/drive/MyDrive/image dataset/natalie portman close shot
#
#
# [!!]Indexing page: 1
#
# [%] Indexed 8 Images on Page 1.
#
# ...
#
# [%] Downloading Image #1 from http://www.vidigy.com/wp-content/uploads/2014/02/Natalie-Portman_260214-12.jpg
# [Error]Invalid image, not saving http://www.vidigy.com/wp-content/uploads/2014/02/Natalie-Portman_260214-12.jpg
#
# [!] Issue getting: http://www.vidigy.com/wp-content/uploads/2014/02/Natalie-Portman_260214-12.jpg
# [!] Error:: Invalid image, not saving http://www.vidigy.com/wp-content/uploads/2014/02/Natalie-Portman_260214-12.jpg
#
# [%] Downloading Image #1 from https://media.glamour.com/photos/5a85952741dbc120f6ef6963/master/pass/natalie-portman.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #2 from https://img.youtube.com/vi/J9lEXw6G4G8/0.jpg
# [%] File Downloaded !
#
# ...
